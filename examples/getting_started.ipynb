# %% [markdown]
# # Getting started: using the LCW-cDFT code

# %% [markdown]
# First you need to create an input file. An example is given in the  `example.in` file.
# The first section has following format:
#
# ```
#
# # FLUID PROPERTIES
#
# model                       = SPC/E
# bulk_density [AA-3]         = 0.03323521
# dcf_kspace [file_path]	    = ../parameters/dcf_ck_SPCE_T300.txt
# temperature [K]             = 300
# chemical_potential [kBT]    = 1e-3
#
# ```
#
# The key parameter to note here is `dcf_kspace` where the correct (relative or absolute) path to the file storing the direct correlation function needs to be specified.
#
#
#
# ```
#
# # COEXISTENCE PROPERTIES
#
# surface_tension [mJ m-2]    = 63.6
# liquid_coex_density [AA-3]  = 0.033234
# vapor_coex_density [AA-3]   = 4.747e-7
# interfacial_thickness [AA]  = 1.54
#
# ```
#
# You then need to specify the parameter for the square gradient functional governing the slowly varying density field.
#
#
#
#
# ```
#
# # EXTERNAL POTENTIAL
#
# solute_type                 = HS
# HS_radius [AA]              = 2
#
# ```
#
# This part specifies that the external potential is from a hard sphere of radius 2 angstrom.
#
#
#
# ```
#
# # COARSE-GRAINING PARAMETERS
#
# a [kJ cm3 mol-2]            = 200
# lambda [angstrom]           = 0.85
#
# ```
#
# The coarse-graining parameter for the potential coupling the slowly varying and rapidly varying component of the density field.
#
#
# Any other optional settings can also be specified in the input file.

# %% [markdown]
# We can first check if the minimisation is sensible by monitoring the convergence of the solution with `minimise_printing.py` in the `src` folder. This code takes the input file via the `-in` flag and (optionally) the output file name via the `-out` flag. This is best done in a notebook environment as below. This should take less than a few minutes.

# %%
# %run ../src/minimise_quartic_printing.py -in example_quartic.in -out example_quartic.out
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# %run ../src/minimise_printing.py -in example.in -out example.out

# %%
# %run ../src/minimise_planar_asymmetric_printing.py -in example_planar_asymmetric.in -out example_planar_asymmetric.out

# %%
# %run ../src/minimise_planar_printing.py -in example_planar.in -out example_planar.out
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /scratch/btb32/cdft-solvation/theory/LCW-cDFT/src/minimise_planar_printing.py:607
#     604 full_dens_new   = update_full_dens(slow_dens_guess, full_dens_guess, 1)
#     605 slow_dens_guess_z = rho_guess
# --> 607 slow_dens_new   = update_slow_dens(full_dens_new, slow_dens_guess_z)
#     608 slow_dens_trial = slow_dens_new
#     609 slow_dens_old   = 0*slow_dens_trial
#
# File /scratch/btb32/cdft-solvation/theory/LCW-cDFT/src/minimise_planar_printing.py:356, in update_slow_dens(rho_full, rho_guess)
#     353 while np.allclose(rho_trial,rho_old, rtol, atol) is False:
#     355     ax.plot(z_ , rho_trial/rho_bulk)
# --> 356     display.display(fig)
#     357     display.clear_output(wait=True)
#     359     rho_old = rho_trial
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/formatters.py:177, in DisplayFormatter.format(self, obj, include, exclude)
#     175 md = None
#     176 try:
# --> 177     data = formatter(obj)
#     178 except:
#     179     # FIXME: log the exception
#     180     raise
#
# File <decorator-gen-2>:2, in __call__(self, obj)
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/formatters.py:221, in catch_format_error(method, self, *args, **kwargs)
#     219 """show traceback on failed format call"""
#     220 try:
# --> 221     r = method(self, *args, **kwargs)
#     222 except NotImplementedError:
#     223     # don't warn on NotImplementedErrors
#     224     return self._check_return(None, args[0])
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/formatters.py:338, in BaseFormatter.__call__(self, obj)
#     336     pass
#     337 else:
# --> 338     return printer(obj)
#     339 # Finally look for special method names
#     340 method = get_real_method(obj, self.print_method)
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/backend_bases.py:2346, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2344 if bbox_inches:
#    2345     if bbox_inches == "tight":
# -> 2346         bbox_inches = self.figure.get_tightbbox(
#    2347             renderer, bbox_extra_artists=bbox_extra_artists)
#    2348         if pad_inches is None:
#    2349             pad_inches = rcParams['savefig.pad_inches']
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/figure.py:1776, in FigureBase.get_tightbbox(self, renderer, bbox_extra_artists)
#    1773     artists = bbox_extra_artists
#    1775 for a in artists:
# -> 1776     bbox = a.get_tightbbox(renderer)
#    1777     if bbox is not None:
#    1778         bb.append(bbox)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/axes/_base.py:4408, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4405     bbox_artists = self.get_default_bbox_extra_artists()
#    4407 for a in bbox_artists:
# -> 4408     bbox = a.get_tightbbox(renderer)
#    4409     if (bbox is not None
#    4410             and 0 < bbox.width < np.inf
#    4411             and 0 < bbox.height < np.inf):
#    4412         bb.append(bbox)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/artist.py:367, in Artist.get_tightbbox(self, renderer)
#     352 def get_tightbbox(self, renderer=None):
#     353     """
#     354     Like `.Artist.get_window_extent`, but includes any clipping.
#     355
#    (...)
#     365         The enclosing bounding box (in figure pixel coordinates).
#     366     """
# --> 367     bbox = self.get_window_extent(renderer)
#     368     if self.get_clip_on():
#     369         clip_box = self.get_clip_box()
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/spines.py:158, in Spine.get_window_extent(self, renderer)
#     156     return bb
#     157 bboxes = [bb]
# --> 158 drawn_ticks = self.axis._update_ticks()
#     160 major_tick = next(iter({*drawn_ticks} & {*self.axis.majorTicks}), None)
#     161 minor_tick = next(iter({*drawn_ticks} & {*self.axis.minorTicks}), None)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/axis.py:1274, in Axis._update_ticks(self)
#    1272 minor_ticks = self.get_minor_ticks(len(minor_locs))
#    1273 self.minor.formatter.set_locs(minor_locs)
# -> 1274 for tick, loc, label in zip(minor_ticks, minor_locs, minor_labels):
#    1275     tick.update_position(loc)
#    1276     tick.set_label1(label)
#
# KeyboardInterrupt:

# %%
# %run ../src/minimise_quartic_printing.py -in example_quartic.in -out example_quartic.out

# %% [markdown]
# LCW-cDFT can be run on the command line using `minimise.py` in the `src` folder analogously.
#
# ```sh
# python3 ../src/minimise.py -in example.in -out example.out
# ```
# ```sh
# python3 ../src/_minimise_lv.py -in example_lv.in -out example_lv.out
# ```
# ```sh
# python3 ../src/minimise_planar.py -in example_planar.in -out example_planar.out
# ```
