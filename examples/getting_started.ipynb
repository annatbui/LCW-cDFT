# %% [markdown]
# # Getting started: using the LCW-cDFT code

# %% [markdown]
# First you need to create an input file. An example is given in the  `example.in` file.
# The first section has following format:
#
# ```
#
# # FLUID PROPERTIES
#
# model                       = SPC/E
# bulk_density [AA-3]         = 0.03323615
# dcf_kspace [file_path]      = ../parameters/dcf_ck_SPCE_T300.txt
# temperature [K]             = 300
# chemical_potential [kBT]    = 1e-3
#
# ```
#
# The key parameter to note here is `dcf_kspace` where the correct (relative or absolute) path to the file storing the direct correlation function needs to be specified.
#
#
#
# ```
# # SQUARE GRADIENT
#
# c [J mol-1 nm9]             = 1.0793454634568314
# d [J mol-1 nm15]            = 30
# m_min [kJ mol-2 cm3 AA2]    = 870
# m_max [kJ mol-2 cm3 AA2]    = 1255
# rho_s_min [AA-3]            = 0.018943804425
# rho_s_max [AA-3]            = 0.0
# liquid_coex_density [AA-3]  = 0.033234078757543585
# vapor_coex_density [AA-3]   = 4.747e-7
#
# ```
#
# You then need to specify the parameter for the square gradient functional governing the slowly varying density field.
#
#
#
# ```
#
# # EXTERNAL POTENTIAL
#
# solute_type                 = HS
# HS_radius [AA]              = 2
#
# ```
#
#
# This part specifies that the external potential is from a hard sphere of radius 2 angstrom.
#
#
#
# ```
#
# # COARSE-GRAINING PARAMETERS
#
# a [kJ cm3 mol-2]            = 200
# lambda [angstrom]           = 0.8
#
# ```
#
# The coarse-graining parameter for the potential coupling the slowly varying and rapidly varying component of the density field.
#
#
# Any other optional settings can also be specified in the input file.

# %% [markdown]
# We can first check if the minimisation is sensible by monitoring the convergence of the solution with `printing_spherical.py` in the `src` folder. This code takes the input file via the `-in` flag and (optionally) the output file name via the `-out` flag. This is best done in a notebook environment as below. This should take less than a few minutes.

# %%
# %run ../src/print_spherical.py -in example_spherical.in -out example_spherical.out 
plt.close("all")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /scratch/btb32/cdft-solvation/theory/LCW-cDFT/src/print_spherical.py:723
#     720 slow_dens_guess_k = get_rFT(full_dens_new, r_) * Gaussian_kspace(k_, 1.5)
#     721 slow_dens_guess_r = rho_guess #get_invrFT(slow_dens_guess_k, k_)
# --> 723 slow_dens_new, SG_m_new   = update_slow_dens(full_dens_new, slow_dens_guess_r)
#     724 slow_dens_trial = slow_dens_new
#     725 slow_dens_old   = 0*slow_dens_trial
#
# File /scratch/btb32/cdft-solvation/theory/LCW-cDFT/src/print_spherical.py:421, in update_slow_dens(rho_full, rho_guess)
#     417 #if SG_m < SG_m_min:
#     418  #   SG_m = SG_m_min
#     420 rho_slow_bar_k = get_rFT(rho_old, r_) * Gaussian_kspace(k_, cg_length)
# --> 421 rho_slow_bar_r = get_invrFT(rho_slow_bar_k, k_)
#     423 first_term = a*np.power(cg_length,2)*rho_full_bar_r/SG_m
#     424 second_term = 0.5 * w_prime(rho_old)*np.power(cg_length,2)/ SG_m
#
# File /scratch/btb32/cdft-solvation/theory/LCW-cDFT/src/print_spherical.py:292, in get_invrFT(f, k)
#     290 for r in r_:
#     291     integrand = k * f * np.sin(k*r) / (r * 2 * np.pi * np.pi)
# --> 292     result.append(integrate.simpson(integrand, k))
#     293 f_r = np.array(result)
#     294 f_r[array_len_last:] = f_r[array_len_last]
#
# File ~/.local/lib/python3.8/site-packages/scipy/integrate/_quadrature.py:552, in simpson(y, x, dx, axis, even)
#     550         first_dx = x[tuple(slice2)] - x[tuple(slice1)]
#     551     val += 0.5*first_dx*(y[slice2]+y[slice1])
# --> 552     result += _basic_simpson(y, 1, N-2, x, dx, axis)
#     553 if even == 'avg':
#     554     val /= 2.0
#
# File ~/.local/lib/python3.8/site-packages/scipy/integrate/_quadrature.py:420, in _basic_simpson(y, start, stop, x, dx, axis)
#     413     hprod = h0 * h1
#     414     h0divh1 = np.true_divide(h0, h1, out=np.zeros_like(h0), where=h1 != 0)
#     415     tmp = hsum/6.0 * (y[slice0] *
#     416                       (2.0 - np.true_divide(1.0, h0divh1,
#     417                                             out=np.zeros_like(h0divh1),
#     418                                             where=h0divh1 != 0)) +
#     419                       y[slice1] * (hsum *
# --> 420                                    np.true_divide(hsum, hprod,
#     421                                                   out=np.zeros_like(hsum),
#     422                                                   where=hprod != 0)) +
#     423                       y[slice2] * (2.0 - h0divh1))
#     424     result = np.sum(tmp, axis=axis)
#     425 return result
#
# KeyboardInterrupt:

# %%
# %run ../src/print_lv.py -in example_lv.in -out example_lv.out 
plt.close("all")

# %%
# %run ../src/print_planar.py -in example_planar.in -out example_planar.out 
plt.close("all")

# %% [markdown]
# LCW-cDFT can be run on the command line using `minimise.py` in the `src` folder analogously.
#
# ```sh
# python3 ../src/minimise_spherical.py -in example_spherical.in -out example_spherical.out
# ```
# ```sh
# python3 ../src/minimise_lv.py -in example_lv.in -out example_lv.out
# ```
# ```sh
# python3 ../src/minimise_planar.py -in example_planar.in -out example_planar.out
# ```
