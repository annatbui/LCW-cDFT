# %%
# %run ../src/minimise_printing.py -in fluid.in

# %%
# %run ../src/minimise.py -in fluid.in
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /scratch/btb32/cdft-solvation/theory/LCW-cDFT/src/minimise.py:487
#     484 slow_density_guess_k = get_rFT(full_density_new, r_) * Gaussian_in_kspace(k_, 1)
#     485 slow_density_guess_r = get_invrFT(slow_density_guess_k, k_)
# --> 487 slow_density_new   = compute_slow_density(full_density_new, slow_density_guess_r)
#     488 slow_density_trial = slow_density_new
#     489 slow_density_old = 0*slow_density_trial
#
# File /scratch/btb32/cdft-solvation/theory/LCW-cDFT/src/minimise.py:297, in compute_slow_density(rho_full, rho_guess)
#     293 rho_old = rho_trial
#     296 rho_slow_bar_k = get_rFT(rho_old, r_) * Gaussian_in_kspace(k_, coarse_grain_length)
# --> 297 rho_slow_bar_r = get_invrFT(rho_slow_bar_k, k_)
#     299 first_term = a*np.power(coarse_grain_length,2)*rho_full_bar_r/m
# ...
